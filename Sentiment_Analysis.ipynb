# %%
from textblob import TextBlob
import numpy as np
import pandas as pd
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import math as m

consumerKey = "ZjFMGUiYGtyoAsM3UvLsimEEu"
consumerSecret = "S1nN0rnpZiHtfg1q6IVDvD88ZZHdjNtqpddtV68h73O0zHEVmS"
accessToken = "1511260824211697667-7sF15Blhl1E52GX8kS7M4ilkpID5QE"
accessTokenSecret = "5Ld7lUqfGAVfrYIxa4myHeWV080cj6dMUjdAWU2dr6xp1"
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth,wait_on_rate_limit=True)

keyword = input('Please enter keyword or hashtag to search:')
noOfTweet = int(input ('Please enter how many tweets to analyze: '))


tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)
positive = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []


def percentage(val, no):
    return (val / no) * 100

for tweet in tweets:
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if  neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1

    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print('total number:' ,len(tweet_list))
print('positive number: ',len(positive_list))
print('negative number: ', len(negative_list))
print('neutral number: ',len(neutral_list))

tweet_list
# Out:
# Please enter keyword or hashtag to search:Engineering
# Please enter how many tweets to analyze: 100
# total number: 100
# positive number:  50
# negative number:  14
# neutral number:  36
#                                                     0
# 0   Get Economics homework help \n\nAccountancy\n\...
# 1   RT @SEOinAfrica: Apply for the @Bloomberg Laun...
# 2   RT @AbutiRowRow: I literally have a degree in ...
# 3   Second year RHS engineering students had to de...
# 4   And, if you blast music at that volume in the ...
# ..                                                ...
# 95  Hello Ugandans, Stop studying Engineering ther...
# 96  💼 Remote Job (📍 Indonesia):\n⭐ HappyFresh is h...
# 97  Students are full engaged &amp; motivated duri...
# 98  Currently, their Ph.D. research focuses on the...
# 99  Congrats Wen! Wen is a food engineering Ph.D. ...
#
# [100 rows x 1 columns]
